# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# ! pip install matplotlib
# ! pip install seaborn

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv(r"C:\Users\chara\OneDrive\Desktop\HACHIMAN\final project\Intelligent Customer Retention Assistant Using Explainable\data\bank_data.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  CIBIL_Score Geography  Gender  Age  Tenure  \
# 0             0           0          619     India  Female   42       2
# 1             1           1          608     India  Female   41       1
# 2             2           2          502     India  Female   42       8
# 3             3           3          699     India  Female   39       1
# 4             4           4          850     India  Female   43       2
#
#    Account_Balance  NumOfProducts  HasCrCard  Digital_Active  Monthly_Income  \
# 0             0.00              1          1               1            8445
# 1         83807.86              1          0               1            9378
# 2        159660.80              3          1               0            9494
# 3             0.00              2          0               0            7818
# 4        125510.82              1          1               1            6590
#
#    Churn           State  UPI_Active Account_Type    Customer_Name
# 0      1      Tamil Nadu           1       Salary        Sneha Rao
# 1      0           Delhi           0       Salary     Lakshmi Iyer
# 2      1  Andhra Pradesh           0      Current       Suman Iyer
# 3      0      Tamil Nadu           1      Savings  Priya Choudhary
# 4      0  Andhra Pradesh           1      Savings    Lakshmi Verma

# %% [markdown]
# # Data Overview

# %%
# df.shape # records and features
# df.info()
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0   CIBIL_Score           Age        Tenure  \
# count   10000.00000  10000.00000  10000.000000  10000.000000  10000.000000
# mean     4999.50000   4999.50000    650.528800     38.921800      5.012800
# std      2886.89568   2886.89568     96.653299     10.487806      2.892174
# min         0.00000      0.00000    350.000000     18.000000      0.000000
# 25%      2499.75000   2499.75000    584.000000     32.000000      3.000000
# 50%      4999.50000   4999.50000    652.000000     37.000000      5.000000
# 75%      7499.25000   7499.25000    718.000000     44.000000      7.000000
# max      9999.00000   9999.00000    850.000000     92.000000     10.000000
#
#        Account_Balance  NumOfProducts    HasCrCard  Digital_Active  \
# count     10000.000000   10000.000000  10000.00000    10000.000000
# mean      76485.889288       1.530200      0.70550        0.515100
# std       62397.405202       0.581654      0.45584        0.499797
# min           0.000000       1.000000      0.00000        0.000000
# 25%           0.000000       1.000000      0.00000        0.000000
# 50%       97198.540000       1.000000      1.00000        1.000000
# 75%      127644.240000       2.000000      1.00000        1.000000
# max      250898.090000       4.000000      1.00000        1.000000
#
#        Monthly_Income         Churn    UPI_Active
# count    10000.000000  10000.000000  10000.000000
# mean      8340.348700      0.203700      0.693300
# std       4792.539807      0.402769      0.461147
# min          0.000000      0.000000      0.000000
# 25%       4249.250000      0.000000      0.000000
# 50%       8349.000000      0.000000      1.000000
# 75%      12448.250000      0.000000      1.000000
# max      16666.000000      1.000000      1.000000

# %% [markdown]
# # Missing Values Check

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# CIBIL_Score        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Account_Balance    0
# NumOfProducts      0
# HasCrCard          0
# Digital_Active     0
# Monthly_Income     0
# Churn              0
# State              0
# UPI_Active         0
# Account_Type       0
# Customer_Name      0
# dtype: int64

# %% [markdown]
# # Traget Variable Distribution

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()

# %% [markdown]
# # Categorical Analysis

# %%
sns.countplot(x='Gender', hue='Churn', data=df)
plt.title("Gender vs Churn")
plt.show()

sns.countplot(x='Geography', hue='Churn', data=df)
plt.title("Geography vs Churn")
plt.show()

# %% [markdown]
# # Numerical Feature Analysis

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.boxplot(x='Churn', y='Account_Balance', data=df)
plt.title("Balance vs Churn")
plt.show()

# %% [markdown]
# # Correlation heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix (Numeric Features)")
plt.show()
