# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
! pip install scikit-learn
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\chara\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\chara\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv(r"C:\Users\chara\OneDrive\Desktop\HACHIMAN\final project\Intelligent Customer Retention Assistant Using Explainable\data\bank_data.csv")

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'CIBIL_Score',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Account_Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'Digital_Active',
#  'Monthly_Income',
#  'Churn',
#  'State',
#  'UPI_Active',
#  'Account_Type',
#  'Customer_Name']

# %% [markdown]
# # Encoded Categorical Variables

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df = pd.get_dummies(df, columns=['Geography'], drop_first=True)

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'CIBIL_Score',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Account_Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'Digital_Active',
#  'Monthly_Income',
#  'Churn',
#  'State',
#  'UPI_Active',
#  'Account_Type',
#  'Customer_Name']

# %%
df = df.drop('Unnamed: 0.1', axis=1)
df = df.drop('Unnamed: 0', axis=1)
df = df.drop('State', axis=1)
df = df.drop('UPI_Active', axis=1)
df = df.drop('Account_Type', axis=1)
# df=df.drop('Customer_Name', axis=1)

# %% [markdown]
# # Feature Target split

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %% [markdown]
# # Train Test Split

# %%
X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import os
pd.DataFrame(X_train).to_csv(r"C:\Users\chara\OneDrive\Desktop\HACHIMAN\final project\Intelligent Customer Retention Assistant Using Explainable\data\processed_data.csv", index=False)

# %%
X_train
# Out:
# array([[ 0.21835119,  0.91186722,  1.91661905, ..., -0.07855688,
#         -0.08904517, -0.09422382],
#        [ 2.05728037,  0.91186722,  0.20210899, ..., -0.07855688,
#         -0.08904517, -0.09422382],
#        [ 0.75860157, -1.09665089, -0.75039661, ..., -0.07855688,
#         -0.08904517, -0.09422382],
#        ...,
#        [ 0.86249588, -1.09665089, -0.08364269, ..., -0.07855688,
#         -0.08904517, -0.09422382],
#        [ 0.15601461,  0.91186722,  0.3926101 , ..., -0.07855688,
#         -0.08904517, -0.09422382],
#        [ 0.46769752,  0.91186722,  1.15461458, ..., -0.07855688,
#         -0.08904517, -0.09422382]])

# %%
df2=pd.read_csv(r"C:\Users\chara\OneDrive\Desktop\HACHIMAN\final project\Intelligent Customer Retention Assistant Using Explainable\data\processed_data.csv")

# %%
df2
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.218351  0.911867  1.916619 -1.731689  1.629928  0.813111 -1.539736
# 1     2.057280  0.911867  0.202109  1.041750 -0.246244 -0.911043  0.649462
# 2     0.758602 -1.096651 -0.750397  0.348390 -1.221027 -0.911043 -1.539736
# 3    -0.082942  0.911867 -0.559895  0.695070  1.574101 -0.911043 -1.539736
# 4     0.530034  0.911867 -0.940898  1.388429 -1.221027  0.813111  0.649462
# ...        ...       ...       ...       ...       ...       ...       ...
# 7495  1.205347  0.911867  1.440366  1.041750 -0.104830 -0.911043  0.649462
# 7496  0.311856 -1.096651  1.821368 -1.385009 -1.221027 -0.911043  0.649462
# 7497  0.862496 -1.096651 -0.083643 -1.385009 -1.221027  2.537266 -1.539736
# 7498  0.156015  0.911867  0.392610  1.041750  1.824777 -0.911043  0.649462
# 7499  0.467698  0.911867  1.154615 -1.385009  1.147221 -0.911043  0.649462
#
# ...
